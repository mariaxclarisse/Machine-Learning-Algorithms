# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
z = np.linspace(-10, 10, 100)

# %%
df = pd.read_csv(r'C:\Users\Clarisse\Documents\Machine Learning Algorithms\data1.csv')
df
# Out:
#       X    Y
# 0 -10.0  0.0
# 1  -7.5  0.2
# 2  -5.0  0.4
# 3  -2.5  0.6
# 4   0.0  0.8
# 5   2.5  1.0
# 6   5.0  NaN
# 7   7.5  NaN
# 8  10.0  NaN

# %%
p = 1/(1+ np.exp(-z))

# %%
plt.xlabel('z')
plt.ylabel('p')
plt.title('Sigmoid function')
plt.plot(z,p)
plt.show()

# %%
plt.xlabel('z')
plt.ylabel('p')
plt.title('Sigmoid function')
plt.show()

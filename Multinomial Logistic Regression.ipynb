# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
z = np.linspace(-10, 10, 100)

# %%
df = pd.read_csv(r'C:\Users\Clarisse\Documents\Machine Learning Algorithms\data3.csv')
df
# Out:
#       X        Y
# 0 -10.0      0.0
# 1  -7.5   2000.0
# 2  -5.0   4000.0
# 3  -2.5   6000.0
# 4   0.0   8000.0
# 5   2.5  10000.0
# 6   5.0      NaN
# 7   7.5      NaN
# 8  10.0      NaN

# %%
p = np.exp(z) / (1 + np.exp(p))

# %%
plt.plot(z,p)

# %%
plt.xlabel('z')
plt.ylabel('p')
plt.title('Logistic Function')
plt.show()
